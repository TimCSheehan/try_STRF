# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp
from matplotlib_venn import *

# %%
venn2(subsets = (3, 2, 1))
plt.show()

# %%
venn2([set(['A', 'B', 'C', 'D']), set(['D', 'E', 'F'])])
plt.show()

# %%
# pow, slope, pow+slope, ent, pow+ent, slope+ent, pow+slope+ent
venn3(subsets = (8.51, 2.67, 1.51, 3.3, 3.81, 7.66, 10.75), set_labels = ('Power', 'Slope', 'Entropy'))
plt.title('Commonality Analysis')
plt.show()
