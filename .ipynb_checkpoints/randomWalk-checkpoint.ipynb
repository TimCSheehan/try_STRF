# %%
import numpy as np
import numpy.random as random
import matplotlib.pyplot as plt
import matplotlib
import math
# %matplotlib inline

# %%
# Produce a random walk process in 2-dimensional space

x_size = 500
y_size = 500

st_x = random.randint(1,x_size) # avoid starting on edges
st_y = random.randint(1,x_size)

n_steps = 2000
ss = 20 # step size

pos_x = np.zeros(n_steps,dtype = int)
pos_y = np.zeros(n_steps,dtype = int)
pos_x[0] = st_x
pos_y[0] = st_y
# tmp = (4,5)
# foo,bar = tmp
# bar

# %%
def rand_walk(n_steps,x_size=500,y_size=500,ss=20,normalize = True,st_pts = (),use_gauss =(),use_cauchy =()):
    if not st_pts:
        st_x = random.randint(1,x_size) # avoid starting on edges
        st_y = random.randint(1,x_size)
    else:
        st_x,st_y = st_pts
    pos_x = np.zeros(n_steps,dtype = float)
    pos_y = np.zeros(n_steps,dtype = float)
    pos_x[0] = st_x
    pos_y[0] = st_y
    
    for i in range(n_steps-1):
        THETA = 2*math.pi*random.rand()
        if use_gauss: ss = np.abs(random.normal(0,use_gauss))
        if use_cauchy and not(use_gauss): ss = np.abs(cauchy_cdf(random.uniform(),use_cauchy))
        d_x = ss*np.cos(THETA)
        d_y =  ss*np.sin(THETA)
        x_prime = round(pos_x[i] +d_x)
        y_prime = round(pos_y[i] +d_y)

        if x_prime >x_size:
            x_prime = x_size - (x_prime-x_size)
        if x_prime < 0:
            x_prime = 0+(0-x_prime)
        if y_prime >y_size:
            y_prime = y_size - (y_prime-y_size)
        if y_prime < 0:
            y_prime = 0+(0-y_prime)
            
        pos_x[i+1] = x_prime
        pos_y[i+1] = y_prime
    if normalize:
        pos_x = np.divide(pos_x,x_size)
        pos_y = np.divide(pos_y,y_size)
    return pos_x, pos_y
def cauchy_cdf(x,gamma): return 1/np.pi*np.arctan(x/gamma)+1/2

# %%
tr0 = rand_walk(n_steps,x_size,y_size,ss)
tr1 = rand_walk(n_steps,x_size,y_size,ss)


plt.plot(tr0[0],tr0[1])
plt.plot(tr1[0],tr1[1])
plt.title('Complete Random Walk')
plt.show()

# %%
def rand_walk_reinit(set_len = 20,n_set = 20,nan_space = True):
    if nan_space: n_pos = (set_len+1)*n_set
    else:  n_pos = set_len*n_set
    pos_y = np.empty(n_pos,dtype = float)
    pos_y.fill(np.nan)
    pos_x = np.empty(n_pos,dtype = float)
    pos_x.fill(np.nan) 
    
    for i in range(n_set):
        if nan_space: win = np.arange(i*set_len+i,(i+1)*set_len+i)
        else: win = np.arange(i*set_len,(i+1)*set_len)
        pos_x[win],pos_y[win] = rand_walk(set_len)
    return pos_x, pos_y

# %%
tr2 = rand_walk_reinit()

plt.plot(tr2[0],tr2[1])
plt.title('Random Walk Restart')
plt.show()

# %%
plt.plot(hubs[0],hubs[1],'ko')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def draw_gauss(scale,cent,sd=3):
    nx = scale
    ny = scale
    RF = np.zeros((nx,ny))
    
    for x in range(nx):
        for y in range(ny):
            disp = cent - [x,y]
            dist = np.sqrt(np.sum((disp)**2))
            val = 1*np.exp(-dist**2/(2*sd**2))
            RF[y,x] += val
    return RF

# %%
RF = draw_gauss(500,np.array([80,40]),20)
plt.imshow(RF)

# %%
def pdist(pos1,pos2):
    disp = pos1-pos2
    dist = np.sqrt(np.sum((disp)**2))
    return dist

# %%
def draw_gausses(scale,centers,stds):
    nx = scale
    ny = scale
    RF = np.zeros((nx,ny))
    ng = np.shape(hubs)[1]
    for x in range(nx):
        for y in range(ny):
            val = 0
            for g in range(ng):
                val += gauss(pdist([x,y],centers[:,g]),stds[g])
                RF[x,y] = val
    return RF
def gauss(x,c=1,a=1,b=0): # x
    return a*np.exp(-((x-b)**2)/(2*c**2))

# %%
# create density grid
scale = 500
n_clusters = 10
# hubs = np.array([[0.1, 0.4, 0.6, 0.9, 0.8],[0.5, 0.2, 0.1, 0.05, 0.6]])*scale
hubs = np.random.uniform(size=(2,n_clusters))*scale
std = np.random.uniform(10,100,n_clusters)
# std = np.array([50, 36 ,67, 70, 200])

# %%
def simulate_density_clusters(scale,n_clusters,normalize=True):
    hubs = np.random.uniform(size=(2,n_clusters))*scale
    std = np.random.uniform(10,100,n_clusters)
    RF = draw_gausses(500,hubs,std)
    if normalize:
        RF = np.divide(RF,np.sum(RF))
    return RF
# mapsfmapsf = maps.flatten()
# mapsf

# %%
RF = simulate_density_clusters(scale,12)
# Out:
# (500, 500)

# %%
#RF_norm = np.divide(RF,np.sum(RF))
# np.shape(RF)
plt.contour(RF)
# plt.colorbar()
plt.title('Simulated Motif Desnsity')
plt.show()

# %%
def weighted_point(RF,n_points):
    nx,ny = np.shape(RF)
    fRF = RF.flatten()
    CDF = np.cumsum(fRF)
    y_pos = np.random.uniform(size=n_points)
    x_pos = np.zeros(n_points)
    for i in range(n_points):
        bool_rank = np.nonzero(CDF>y_pos[i])[0]
        x_pos[i] = bool_rank[0]-1 # minus 1 to get index before sign change
    x_pos_og = ind_get(nx,x_pos)
    return CDF, x_pos, y_pos, x_pos_og

def ind_get(nx,x_pos):
#     row = x_pos//nx
#     col = (x_pos-1)%nx
#     return row,col
    return x_pos//nx, (x_pos-1)%nx
    
        

CDF,x_pos,y_pos,x_og = weighted_point(RF,1000)
plt.plot(CDF)
plt.plot(x_pos,y_pos,'ko')
plt.title('Cumulative Density Function')
plt.xlabel('Image Point')
plt.show()

plt.contour(RF)
plt.plot(x_og[1],x_og[0],'k.')
plt.show()

# %%
# mapsf = maps.flatten()
# mapsf
def rand_walk_reinit_weight(RF,set_len = 20,n_set = 20,nan_space = True,use_gauss = (),use_cauchy=()):
    if nan_space: n_pos = (set_len+1)*n_set
    else:  n_pos = set_len*n_set
    pos_y = np.empty(n_pos,dtype = float)
    pos_y.fill(np.nan)
    pos_x = np.empty(n_pos,dtype = float)
    pos_x.fill(np.nan) 
    _,_,_,st_pos = weighted_point(RF,n_set)
    
    for i in range(n_set):
        if nan_space: win = np.arange(i*set_len+i,(i+1)*set_len+i)
        else: win = np.arange(i*set_len,(i+1)*set_len)
        pos_x[win],pos_y[win] = rand_walk(set_len,st_pts=(st_pos[0][i],st_pos[1][i]),use_gauss=use_gauss,use_cauchy=use_cauchy)
    return pos_x, pos_y

# %%
x_loc = rand_walk_reinit_weight(RF)
scl = np.arange(0,1,1.0/scale)
plt.contour(scl,scl,RF)
plt.plot(x_loc[1],x_loc[0],'.k-')
plt.show()

# %% [markdown]
# # Gauss random walk

# %%
x_loc_g = rand_walk_reinit_weight(RF,set_len = 10,n_set = 35,nan_space = True,use_cauchy = 1.0)
scl = np.arange(0,1,1.0/scale)
plt.contour(scl,scl,RF)
plt.plot(x_loc_g[1],x_loc_g[0],'.k-')
plt.show()

# %%
x_loc_g
# Out:
# (array([ 0.766,  0.776,  0.79 ,  0.762,  0.78 ,  0.824,  0.812,  0.788,
#          0.784,  0.768,    nan,  0.73 ,  0.734,  0.722,  0.746,  0.788,
#          0.806,  0.864,  0.904,  0.956,  0.964,    nan,  0.276,  0.26 ,
#          0.266,  0.278,  0.272,  0.268,  0.31 ,  0.35 ,  0.378,  0.376,
#            nan,  0.414,  0.432,  0.41 ,  0.486,  0.426,  0.48 ,  0.436,
#          0.388,  0.326,  0.36 ,    nan,  0.372,  0.376,  0.454,  0.416,
#          0.446,  0.45 ,  0.472,  0.5  ,  0.444,  0.338,    nan,  0.35 ,
#          0.354,  0.364,  0.304,  0.336,  0.358,  0.388,  0.398,  0.296,
#          0.278,    nan,  0.58 ,  0.58 ,  0.614,  0.596,  0.616,  0.526,
#          0.57 ,  0.552,  0.692,  0.68 ,    nan,  0.442,  0.54 ,  0.51 ,
#          0.56 ,  0.546,  0.544,  0.528,  0.552,  0.624,  0.594,    nan,
#          0.454,  0.492,  0.404,  0.47 ,  0.468,  0.39 ,  0.306,  0.308,
#          0.274,  0.276,    nan,  0.48 ,  0.406,  0.488,  0.482,  0.396,
#          0.36 ,  0.368,  0.364,  0.362,  0.368,    nan,  0.348,  0.342,
#          0.418,  0.438,  0.404,  0.416,  0.4  ,  0.348,  0.35 ,  0.328,
#            nan,  0.244,  0.232,  0.322,  0.338,  0.302,  0.288,  0.236,
#          0.254,  0.262,  0.246,    nan,  0.524,  0.506,  0.506,  0.508,
#          0.444,  0.496,  0.412,  0.408,  0.4  ,  0.406,    nan,  0.956,
#          0.984,  0.95 ,  0.948,  0.934,  0.926,  0.954,  0.95 ,  0.948,
#          0.964,    nan,  0.674,  0.632,  0.616,  0.564,  0.572,  0.572,
#          0.664,  0.716,  0.714,  0.714,    nan,  0.442,  0.414,  0.414,
#          0.426,  0.376,  0.374,  0.362,  0.356,  0.314,  0.308,    nan,
#          0.254,  0.252,  0.252,  0.244,  0.228,  0.228,  0.24 ,  0.204,
#          0.204,  0.148,    nan,  0.342,  0.36 ,  0.364,  0.364,  0.404,
#          0.404,  0.344,  0.38 ,  0.428,  0.41 ,    nan,  0.588,  0.504,
#          0.498,  0.526,  0.522,  0.494,  0.528,  0.524,  0.488,  0.472,
#            nan,  0.5  ,  0.522,  0.586,  0.588,  0.592,  0.622,  0.574,
#          0.62 ,  0.63 ,  0.636,    nan,  0.316,  0.29 ,  0.246,  0.278,
#            nan,  0.966,  0.966,  0.992,  0.974,  1.   ,  0.986,  0.972,
#          0.974,  0.982,  0.99 ,    nan,  0.468,  0.398,  0.396,  0.41 ,
#          0.446,  0.438,  0.49 ,  0.486,  0.556,  0.604,    nan,  0.632,
#          0.65 ,  0.722,  0.716,  0.714,  0.718,  0.762,  0.754,  0.752,
#          0.73 ,    nan,  0.808,  0.798,  0.774,  0.768,  0.714,  0.71 ,
#          0.772,  0.824,  0.822,  0.824,    nan,  0.548,  0.542,  0.542,
#          0.546,  0.522,  0.512,  0.47 ,  0.47 ,  0.45 ,  0.454,    nan,
#          0.57 ,  0.546,  0.548,  0.526,  0.506,  0.53 ,  0.47 ,  0.458,
#          0.458,  0.476,    nan,  0.896,  0.84 ,  0.842,  0.842,  0.942,
#          0.928,  0.908,  0.896,  0.896,  0.89 ,    nan,  0.408,  0.408,
#          0.32 ,  0.334,  0.358,  0.38 ,  0.368,  0.384,  0.344,  0.3  ,
#            nan,  0.394,  0.336,  0.4  ,  0.402,  0.39 ,  0.476,  0.456,
#          0.45 ,  0.436,  0.454,    nan,  0.838,  0.798,  0.844,  0.81 ,
#          0.816,  0.824,  0.832,  0.774,  0.722,  0.74 ,    nan,  0.232,
#          0.262,  0.29 ,  0.208,  0.222,  0.174,  0.174,  0.178,  0.2  ,
#          0.132,    nan,  0.074,  0.066,  0.072,  0.004,  0.068,  0.096,
#          0.152,  0.158,  0.17 ,  0.184,    nan,  0.712,  0.71 ,  0.712,
#          0.712,  0.648,  0.688,  0.68 ,  0.672,  0.644,  0.61 ,    nan,
#          0.72 ,  0.696,  0.702,  0.708,  0.694,  0.71 ,  0.712,  0.698,
#          0.788,  0.8  ,    nan,  0.488,  0.456,  0.446,  0.446,  0.438,
#          0.438,  0.36 ,  0.386,  0.364,  0.316,    nan,  0.494,  0.53 ,
#          0.466,  0.454,  0.458,  0.444,  0.52 ,  0.592,  0.598,  0.682,
#            nan,  0.734,  0.778,  0.718,  0.704,  0.676,  0.656,  0.656,
#          0.65 ,  0.612,  0.61 ,    nan,  0.392,  0.434,  0.42 ,  0.528,
#          0.586,  0.586,  0.58 ,  0.594,  0.612,  0.616,    nan,  0.448,
#          0.434,  0.46 ,  0.442,  0.418,  0.418,  0.412,  0.418,  0.36 ,
#          0.382,    nan,  0.48 ,  0.482,  0.484,  0.502,  0.468,  0.476,
#          0.514,  0.522,  0.58 ,  0.59 ,    nan,  0.398,  0.418,  0.422,
#          0.402,  0.402,  0.4  ,  0.388,  0.456,  0.454,  0.454,    nan,
#          0.212,  0.162,  0.216,  0.204,  0.238,  0.228,  0.224,  0.224,
#          0.122,  0.148,    nan,  0.742,  0.758,  0.746,  0.74 ,  0.738,
#          0.736,  0.742,  0.788,  0.768,  0.738,    nan,  0.744,  0.718,
#          0.772,  0.704,  0.694,  0.674,  0.66 ,  0.65 ,  0.644,  0.658,
#            nan]))

# %%
random.uniform()
# Out:
# 0.11765966361873403

# %%
foo = cauchy_cdf(random.uniform(size=20000),1)
plt.hist(foo)
plt.show()
